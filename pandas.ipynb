# %%
import pandas as pd

# %%
data = [
    ["rahul",22,87],
    ["lucky",21,98],
    ["sumit",22,82],
    ["pushkar",22,90],
    ["jany",19,78],
    ["krish",22,45],
    ["khushi",19,23],
    ["kaku",20,90],
    ["nakul",21,86],
    ["jyoti",23,99]
]

df = pd.DataFrame(data, columns=["Name", "Age", "Marks"])

print(df)
# Out:
#       Name  Age  Marks
# 0    rahul   22     87
# 1    lucky   21     98
# 2    sumit   22     82
# 3  pushkar   22     90
# 4     jany   19     78
# 5    krish   22     45
# 6   khushi   19     23
# 7     kaku   20     90
# 8    nakul   21     86
# 9    jyoti   23     99

# %%
above_85=df[df["Marks"]>85]
print(above_85)
# Out:
#       Name  Age  Marks
# 0    rahul   22     87
# 1    lucky   21     98
# 3  pushkar   22     90
# 7     kaku   20     90
# 8    nakul   21     86
# 9    jyoti   23     99

# %%
print(df["Marks"].mean())
# Out:
# 77.8

# %%
print(df["Marks"].max())
# Out:
# 99
